# %% [markdown]
# <a href="https://colab.research.google.com/github/prk-akshat/covid19analysis/blob/master/dataanalysis1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
covid_confirmed_dataset=pd.read_csv("/content/time_series_covid_19_confirmed.csv")

# %%
covid_confirmed_dataset.head()
# Out:
#   Province/State Country/Region       Lat  ...  7/30/20  7/31/20  8/1/20
# 0            NaN    Afghanistan  33.93911  ...    36542    36675   36710
# 1            NaN        Albania  41.15330  ...     5197     5276    5396
# 2            NaN        Algeria  28.03390  ...    29831    30394   30950
# 3            NaN        Andorra  42.50630  ...      922      925     925
# 4            NaN         Angola -11.20270  ...     1109     1148    1164
#
# [5 rows x 197 columns]

# %%
covid_confirmed_dataset.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '7/23/20', '7/24/20', '7/25/20', '7/26/20', '7/27/20', '7/28/20',
#        '7/29/20', '7/30/20', '7/31/20', '8/1/20'],
#       dtype='object', length=197)

# %%
covid_confirmed_dataset.drop(["Lat","Long"],axis=1,inplace=True)

# %%
covid_confirmed_dataset
# Out:
#     Province/State         Country/Region  1/22/20  ...  7/30/20  7/31/20  8/1/20
# 0              NaN            Afghanistan        0  ...    36542    36675   36710
# 1              NaN                Albania        0  ...     5197     5276    5396
# 2              NaN                Algeria        0  ...    29831    30394   30950
# 3              NaN                Andorra        0  ...      922      925     925
# 4              NaN                 Angola        0  ...     1109     1148    1164
# ..             ...                    ...      ...  ...      ...      ...     ...
# 261            NaN  Sao Tome and Principe        0  ...      870      871     874
# 262            NaN                  Yemen        0  ...     1726     1728    1730
# 263            NaN                Comoros        0  ...      378      378     386
# 264            NaN             Tajikistan        0  ...     7366     7409    7451
# ...

# %%
covid_deaths_dataset_csv=pd.read_csv("/content/time_series_covid_19_deaths.csv")

# %%
covid_recovered_dataset_csv=pd.read_csv("/content/time_series_covid_19_recovered.csv")

# %%
covid_confirmed_aggregated=covid_confirmed_dataset.groupby("Country/Region").sum()

# %%
covid_confirmed_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  7/30/20  7/31/20  8/1/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...    36542    36675   36710
# Albania               0        0        0  ...     5197     5276    5396
# Algeria               0        0        0  ...    29831    30394   30950
# Andorra               0        0        0  ...      922      925     925
# Angola                0        0        0  ...     1109     1148    1164
#
# [5 rows x 193 columns]

# %%
covid_deaths_aggregated=covid_deaths_dataset_csv.groupby("Country/Region").sum()

# %%
covid_deaths_aggregated.head(
)
# Out:
#                      Lat       Long  1/22/20  ...  7/30/20  7/31/20  8/1/20
# Country/Region                                ...
# Afghanistan     33.93911  67.709953        0  ...     1271     1272    1283
# Albania         41.15330  20.168300        0  ...      154      157     161
# Algeria         28.03390   1.659600        0  ...     1200     1210    1223
# Andorra         42.50630   1.521800        0  ...       52       52      52
# Angola         -11.20270  17.873900        0  ...       51       52      54
#
# [5 rows x 195 columns]

# %%
covid_deaths_aggregated.drop(["Lat","Long"],axis=1,inplace=True)

# %%
covid_deaths_aggregated.head(
    
)
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  7/30/20  7/31/20  8/1/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1271     1272    1283
# Albania               0        0        0  ...      154      157     161
# Algeria               0        0        0  ...     1200     1210    1223
# Andorra               0        0        0  ...       52       52      52
# Angola                0        0        0  ...       51       52      54
#
# [5 rows x 193 columns]

# %%
covid_recovered_aggregated=covid_recovered_dataset_csv.groupby("Country/Region").sum()

# %%
covid_recovered_aggregated.drop(["Lat","Long"],axis=1,inplace=True)

# %%
covid_recovered_aggregated.head(
    
)
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  7/30/20  7/31/20  8/1/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...    25471    25509   25509
# Albania               0        0        0  ...     2883     2952    2961
# Algeria               0        0        0  ...    20082    20537   20988
# Andorra               0        0        0  ...      806      807     807
# Angola                0        0        0  ...      395      437     460
#
# [5 rows x 193 columns]

# %%
covid_confirmed_aggregated.loc['India'].plot()

# %%
covid_deaths_aggregated.loc['India'].plot()

# %%
covid_recovered_aggregated.loc['India'].plot(
    
)

# %%
covid_confirmed_aggregated.loc['India'].plot()
covid_deaths_aggregated.loc['India'].plot()
covid_recovered_aggregated.loc['India'].plot()

# %%
covid_confirmed_aggregated.loc["India"].diff().plot()

# %%
covid_deaths_aggregated.loc["India"].diff().plot()

# %%
covid_recovered_aggregated.loc["India"].diff().plot()

# %%
covid_confirmed_aggregated.loc["India"].diff().plot()
covid_deaths_aggregated.loc["India"].diff().plot()
covid_recovered_aggregated.loc["India"].diff().plot()

# %%
covid_confirmed_aggregated.loc["India"].diff().max()
# Out:
# 61242.0

# %%
covid_deaths_aggregated.loc["India"].diff().max()
# Out:
# 2003.0

# %%
covid_recovered_aggregated.loc["India"].diff().max()
# Out:
# 51255.0

# %%
countries=list(covid_confirmed_aggregated.index)
max_infection_rate= []
for c in countries:
  max_infection_rate.append(covid_confirmed_aggregated.loc[c].diff().max())
covid_confirmed_aggregated["max_infection_rate"]= max_infection_rate

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-3f1bf81d7f85> in <module>()
# ----> 1 max_infection_rate.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
covid_confirmed_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  7/31/20  8/1/20  max_infection_rate
# Country/Region                             ...
# Afghanistan           0        0        0  ...    36675   36710               915.0
# Albania               0        0        0  ...     5276    5396               126.0
# Algeria               0        0        0  ...    30394   30950               675.0
# Andorra               0        0        0  ...      925     925                79.0
# Angola                0        0        0  ...     1148    1164                78.0
#
# [5 rows x 194 columns]

# %%
confirmed_data= pd.DataFrame(covid_confirmed_aggregated["max_infection_rate"])

# %%
confirmed_data
# Out:
#                     max_infection_rate
# Country/Region
# Afghanistan                      915.0
# Albania                          126.0
# Algeria                          675.0
# Andorra                           79.0
# Angola                            78.0
# ...                                ...
# West Bank and Gaza               501.0
# Western Sahara                     4.0
# Yemen                            116.0
# Zambia                           915.0
# Zimbabwe                         490.0
#
# [188 rows x 1 columns]

# %%
countries=list(covid_deaths_aggregated.index)
max_death_rate= []
for c in countries:
  max_death_rate.append(covid_deaths_aggregated.loc[c].diff().max())
covid_deaths_aggregated["max_death_rate"]= max_death_rate

# %%
deaths_data=pd.DataFrame(covid_deaths_aggregated["max_death_rate"])

# %%
deaths_data
# Out:
#                     max_death_rate
# Country/Region
# Afghanistan                   46.0
# Albania                        6.0
# Algeria                       30.0
# Andorra                        4.0
# Angola                         6.0
# ...                            ...
# West Bank and Gaza             7.0
# Western Sahara                 1.0
# Yemen                         52.0
# Zambia                        67.0
# Zimbabwe                      14.0
#
# [188 rows x 1 columns]

# %%
countries=list(covid_recovered_aggregated.index)
max_recovery_rate= []
for c in countries:
  max_recovery_rate.append(covid_recovered_aggregated.loc[c].diff().max())
covid_recovered_aggregated["max_recovery_rate"]= max_recovery_rate

# %%
recovery_data=pd.DataFrame(covid_recovered_aggregated["max_recovery_rate"])

# %%
recovery_data
# Out:
#                     max_recovery_rate
# Country/Region
# Afghanistan                    1930.0
# Albania                          85.0
# Algeria                         749.0
# Andorra                          57.0
# Angola                           94.0
# ...                               ...
# West Bank and Gaza             1081.0
# Western Sahara                    5.0
# Yemen                           180.0
# Zambia                          514.0
# Zimbabwe                        283.0
#
# [188 rows x 1 columns]

# %%
countries=list(covid_confirmed_aggregated.index)
total_infection= []
for c in countries:
  total_infection.append(covid_confirmed_aggregated.loc[c].sum())
confirmed_data["total_infection"]= total_infection

# %%
confirmed_data
# Out:
#                     max_infection_rate  total_infection
# Country/Region
# Afghanistan                      915.0        6360213.0
# Albania                          126.0         668397.0
# Algeria                          675.0        3988347.0
# Andorra                           79.0         297240.0
# Angola                            78.0          84717.0
# ...                                ...              ...
# West Bank and Gaza               501.0         875187.0
# Western Sahara                     4.0           2865.0
# Yemen                            116.0         227682.0
# Zambia                           915.0         474999.0
# Zimbabwe                         490.0         200700.0
#
# [188 rows x 2 columns]

# %%
countries=list(covid_recovered_aggregated.index)
total_recovery= []
for c in countries:
  total_recovery.append(covid_recovered_aggregated.loc[c].sum())
recovery_data["total_recovery"]= total_recovery

# %%
recovery_data
# Out:
#                     max_recovery_rate  total_recovery
# Country/Region
# Afghanistan                    1930.0        927406.0
# Albania                          85.0        133377.0
# Algeria                         749.0        857078.0
# Andorra                          57.0         73158.0
# Angola                           94.0          8526.0
# ...                               ...             ...
# West Bank and Gaza             1081.0         86207.0
# Western Sahara                    5.0           693.0
# Yemen                           180.0         28228.0
# Zambia                          514.0        101827.0
# Zimbabwe                        283.0         16920.0
#
# [188 rows x 2 columns]

# %%
countries=list(covid_deaths_aggregated.index)
total_death= []
for c in countries:
  total_death.append(covid_deaths_aggregated.loc[c].sum())
deaths_data["total_death"]= total_death

# %%
deaths_data
# Out:
#                     max_death_rate  total_death
# Country/Region
# Afghanistan                   46.0      55511.0
# Albania                        6.0       6484.0
# Algeria                       30.0      83995.0
# Andorra                        4.0       5687.0
# Angola                         6.0       1336.0
# ...                            ...          ...
# West Bank and Gaza             7.0       1782.0
# Western Sahara                 1.0         69.0
# Yemen                         52.0      20202.0
# Zambia                        67.0       3463.0
# Zimbabwe                      14.0       1165.0
#
# [188 rows x 2 columns]

# %%
data1= confirmed_data.join(deaths_data,how="inner")

# %%
data1
# Out:
#                     max_infection_rate  ...  total_death
# Country/Region                          ...
# Afghanistan                      915.0  ...      55511.0
# Albania                          126.0  ...       6484.0
# Algeria                          675.0  ...      83995.0
# Andorra                           79.0  ...       5687.0
# Angola                            78.0  ...       1336.0
# ...                                ...  ...          ...
# West Bank and Gaza               501.0  ...       1782.0
# Western Sahara                     4.0  ...         69.0
# Yemen                            116.0  ...      20202.0
# Zambia                           915.0  ...       3463.0
# Zimbabwe                         490.0  ...       1165.0
#
# [188 rows x 4 columns]

# %%
data_final=data1.join(recovery_data,how="inner")

# %%
data_final
# Out:
#                     max_infection_rate  ...  total_recovery
# Country/Region                          ...
# Afghanistan                      915.0  ...        927406.0
# Albania                          126.0  ...        133377.0
# Algeria                          675.0  ...        857078.0
# Andorra                           79.0  ...         73158.0
# Angola                            78.0  ...          8526.0
# ...                                ...  ...             ...
# West Bank and Gaza               501.0  ...         86207.0
# Western Sahara                     4.0  ...           693.0
# Yemen                            116.0  ...         28228.0
# Zambia                           915.0  ...        101827.0
# Zimbabwe                         490.0  ...         16920.0
#
# [188 rows x 6 columns]

# %%
x=data_final["total_infection"]
y=data_final["total_death"]
sns.scatterplot(x,np.log(y))
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
x=data_final["total_infection"]
y=data_final["total_recovery"]
sns.scatterplot(x,y)
